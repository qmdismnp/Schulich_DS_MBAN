# %%
pip install lime
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting lime
#   Downloading lime-0.2.0.1.tar.gz (275 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.7/275.7 kB 1.1 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from lime) (3.9.1)
# Requirement already satisfied: numpy in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from lime) (2.0.0)
# Requirement already satisfied: scipy in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from lime) (1.13.1)
# Collecting tqdm (from lime)
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 850.1 kB/s eta 0:00:00:--:--
# Requirement already satisfied: scikit-learn>=0.18 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from lime) (1.5.1)
# Collecting scikit-image>=0.12 (from lime)
#   Downloading scikit_image-0.24.0-cp39-cp39-macosx_12_0_arm64.whl.metadata (14 kB)
# Collecting networkx>=2.8 (from scikit-image>=0.12->lime)
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: pillow>=9.1 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from scikit-image>=0.12->lime) (10.4.0)
# Collecting imageio>=2.33 (from scikit-image>=0.12->lime)
#   Downloading imageio-2.35.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image>=0.12->lime)
#   Downloading tifffile-2024.8.30-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from scikit-image>=0.12->lime) (24.1)
# Collecting lazy-loader>=0.4 (from scikit-image>=0.12->lime)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: joblib>=1.2.0 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from scikit-learn>=0.18->lime) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from scikit-learn>=0.18->lime) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from matplotlib->lime) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from matplotlib->lime) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from matplotlib->lime) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from matplotlib->lime) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from matplotlib->lime) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from matplotlib->lime) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib->lime) (3.19.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->lime) (1.15.0)
# Downloading scikit_image-0.24.0-cp39-cp39-macosx_12_0_arm64.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 731.2 kB/s eta 0:00:0000:0100:01
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 483.0 kB/s eta 0:00:00a 0:00:01
# Downloading imageio-2.35.1-py3-none-any.whl (315 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.4/315.4 kB 539.2 kB/s eta 0:00:00a 0:00:01
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 463.3 kB/s eta 0:00:0000:0100:01
# Downloading tifffile-2024.8.30-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 kB 464.3 kB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: lime
#   Building wheel for lime (setup.py) ... done
#   Created wheel for lime: filename=lime-0.2.0.1-py3-none-any.whl size=283857 sha256=7a439af90f850c839b9159f78d15e10d7a4fb2acbcaf9c189c9b986c48cd2ebc
#   Stored in directory: /Users/huiyisang/Library/Caches/pip/wheels/ed/d7/c9/5a0130d06d6310bc6cbe55220e6e72dcb8c4eff9a478717066
# Successfully built lime
# Installing collected packages: tqdm, tifffile, networkx, lazy-loader, imageio, scikit-image, lime
# Successfully installed imageio-2.35.1 lazy-loader-0.4 lime-0.2.0.1 networkx-3.2.1 scikit-image-0.24.0 tifffile-2024.8.30 tqdm-4.66.5
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install shap
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting shap
#   Downloading shap-0.46.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (24 kB)
# Requirement already satisfied: numpy in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from shap) (2.0.0)
# Requirement already satisfied: scipy in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from shap) (1.5.1)
# Requirement already satisfied: pandas in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from shap) (4.66.5)
# Requirement already satisfied: packaging>20.9 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from shap) (24.1)
# Collecting slicer==0.0.8 (from shap)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Collecting numba (from shap)
#   Downloading numba-0.60.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting cloudpickle (from shap)
#   Downloading cloudpickle-3.0.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting llvmlite<0.44,>=0.43.0dev0 (from numba->shap)
#   Downloading llvmlite-0.43.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: joblib>=1.2.0 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/huiyisang/Library/Python/3.9/lib/python/site-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.15.0)
# Downloading shap-0.46.0-cp39-cp39-macosx_11_0_arm64.whl (455 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.8/455.8 kB 544.0 kB/s eta 0:00:00a 0:00:01
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Downloading cloudpickle-3.0.0-py3-none-any.whl (20 kB)
# Downloading numba-0.60.0-cp39-cp39-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 412.8 kB/s eta 0:00:0000:0100:01
# Downloading llvmlite-0.43.0-cp39-cp39-macosx_11_0_arm64.whl (28.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 327.6 kB/s eta 0:00:0000:0100:03
# Installing collected packages: slicer, llvmlite, cloudpickle, numba, shap
# Successfully installed cloudpickle-3.0.0 llvmlite-0.43.0 numba-0.60.0 shap-0.46.0 slicer-0.0.8
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
import pandas as pd
import seaborn as sns
import numpy as np

# %%
iris = load_iris()

# %%
X = iris.data
y = iris.target

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2)

# %%
df = pd.DataFrame(np.c_[iris['data'], iris['target']])

# %%
df
# Out:
#        0    1    2    3    4
# 0    5.1  3.5  1.4  0.2  0.0
# 1    4.9  3.0  1.4  0.2  0.0
# 2    4.7  3.2  1.3  0.2  0.0
# 3    4.6  3.1  1.5  0.2  0.0
# 4    5.0  3.6  1.4  0.2  0.0
# ..   ...  ...  ...  ...  ...
# 145  6.7  3.0  5.2  2.3  2.0
# 146  6.3  2.5  5.0  1.9  2.0
# 147  6.5  3.0  5.2  2.0  2.0
# 148  6.2  3.4  5.4  2.3  2.0
# 149  5.9  3.0  5.1  1.8  2.0
#
# [150 rows x 5 columns]

# %%
df.columns = ['sep_length', 'sep_width', 'pet_length', 'pet_width', 'target']

# %%
sns.lmplot(x='sep_length', y='sep_width', hue='target', data=df)

# %%
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
lr_model = LogisticRegression(random_state=42)
lr_model.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
from sklearn.metrics import accuracy_score
rf_pred = rf_model.predict(X_test)
print(accuracy_score(rf_pred,y_test))

lr_pred = lr_model.predict(X_test)
print(accuracy_score(lr_pred,y_test))
# Out:
# 0.9333333333333333
# 0.9
